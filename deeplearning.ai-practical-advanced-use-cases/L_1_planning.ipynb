# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Breakdown for Small Business Website
#
# #### Overview
# This project aims to create a responsive website for a small business that showcases their services, shares their story, and facilitates customer communication. Below is a comprehensive list of tasks with detailed descriptions, timelines, dependencies, and deliverables.
#
# ---
#
# #### Task Breakdown
#
# 1. **Create Wireframes & Mockups**
#    - **Description**: Draft wireframes and mockups for the website layout for both desktop and mobile. Ensure design meets user experience standards.
#    - **Timeline**: Week 1
#    - **Dependencies**: None
#    - **Deliverables**: Wireframes and mockups in PDF/PNG format
#    - **Responsible**: Bob Smith
#
# 2. **Design the User Interface**
#    - **Description**: Develop a modern, clean user interface based on approved mockups.
#    - **Timeline**: Weeks 2-3
#    - **Dependencies**: Completion of wireframes and mockups.
#    - **Deliverables**: UI assets (CSS, images, etc.)
#    - **Responsible**: Bob Smith
#
# 3. **Develop Frontend Structure**
#    - **Description**: Code the frontend of the website including responsive design implementation using HTML, CSS, and JavaScript.
#    - **Timeline**: Weeks 4-5
#    - **Dependencies**: Completion of UI design.
#    - **Deliverables**: Frontend code (HTML/CSS/JS)
#    - **Responsible**: Jane Doe
#
# 4. **Implement Navigation System**
#    - **Description**: Design and implement a user-friendly navigation system with an intuitive menu structure.
#    - **Timeline**: Weeks 4-5
#    - **Dependencies**: Completion of frontend structure.
#    - **Deliverables**: Functional navigation menu
#    - **Responsible**: Jane Doe
#
# 5. **Develop "About Us" Page**
#    - **Description**: Create a dedicated "About Us" page that highlights the company’s history and values.
#    - **Timeline**: Week 6
#    - **Dependencies**: Completion of frontend structure.
#    - **Deliverables**: "About Us" page live on the website
#    - **Responsible**: Jane Doe
#
# 6. **Design "Services" Page**
#    - **Description**: Design and develop a "Services" page that showcases the offerings with descriptions.
#    - **Timeline**: Week 7
#    - **Dependencies**: Completion of frontend structure.
#    - **Deliverables**: "Services" page live on the website
#    - **Responsible**: Jane Doe
#
# 7. **Create "Contact Us" Page**
#    - **Description**: Develop a “Contact Us” page including a contact form and integrated map.
#    - **Timeline**: Week 8
#    - **Dependencies**: Completion of "Services" page.
#    - **Deliverables**: Live "Contact Us" page with functional form and map
#    - **Responsible**: Jane Doe
#
# 8. **Implement Blog Section**
#    - **Description**: Create a section for posting industry news and company updates.
#    - **Timeline**: Week 9
#    - **Dependencies**: Completion of "Contact Us" page.
#    - **Deliverables**: Blog section live on the website
#    - **Responsible**: Jane Doe
#
# 9. **Optimize for SEO and Speed**
#    - **Description**: Optimize website for search engines and ensure fast loading times.
#    - **Timeline**: Week 10
#    - **Dependencies**: Completion of all pages.
#    - **Deliverables**: SEO audit report and improved loading times
#    - **Responsible**: Jane Doe
#
# 10. **Integrate Social Media Links**
#     - **Description**: Add social media links and sharing capabilities to all relevant pages.
#     - **Timeline**: Week 10
#     - **Dependencies**: Completion of all pages.
#     - **Deliverables**: Social media links integrated
#     - **Responsible**: Jane Doe
#
# 11. **Add Testimonials Section**
#     - **Description**: Design and implement a testimonials section to showcase customer feedback.
#     - **Timeline**: Week 11
#     - **Dependencies**: Completion of all pages.
#     - **Deliverables**: Testimonials section live on the website
#     - **Responsible**: Jane Doe
#
# 12. **Testing Phase**
#     - **Description**: Conduct thorough testing for bugs and performance issues. Apply necessary fixes.
#     - **Timeline**: Weeks 12-13
#     - **Dependencies**: Completion of all previous tasks.
#     - **Deliverables**: Bug report and resolved website issues
#     - **Responsible**: Alice Johnson, Tom Brown
#
# 13. **Launch Website**
#     - **Description**: Finalize and launch the website, making it available to the public.
#     - **Timeline**: Week 14
#     - **Dependencies**: Completion of testing.
#     - **Deliverables**: Live website
#     - **Responsible**: John Doe
#
# ---
#
# ### Gantt Chart Visualization
#
# | Task                         | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 | Week 13 | Week 14 |
# |------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|---------|---------|
# | Create Wireframes & Mockups   |   ✔   |        |        |        |        |        |        |        |        |         |         |         |         |         |
# | Design User Interface         |        |   ✔    |   ✔    |        |        |        |        |        |        |         |         |         |         |         |
# | Develop Frontend Structure    |        |        |        |   ✔    |   ✔    |        |        |        |        |         |         |         |         |         |
# | Implement Navigation System    |        |        |        |   ✔    |   ✔    |        |        |        |        |         |         |         |         |         |
# | Develop "About Us" Page      |        |        |        |        |        |   ✔    |        |        |        |         |         |         |         |         |
# | Design "Services" Page       |        |        |        |        |        |        |   ✔    |        |        |         |         |         |         |         |
# | Create "Contact Us" Page     |        |        |        |        |        |        |        |   ✔    |        |         |         |         |         |         |
# | Implement Blog Section        |        |        |        |        |        |        |        |        |   ✔    |         |         |         |         |         |
# | Optimize for SEO and Speed   |        |        |        |        |        |        |        |        |        |   ✔     |         |         |         |         |
# | Integrate Social Media Links   |        |        |        |        |        |        |        |        |        |   ✔     |         |         |         |         |
# | Add Testimonials Section      |        |        |        |        |        |        |        |        |        |         |   ✔     |         |         |         |
# | Testing Phase                 |        |        |        |        |        |        |        |        |        |         |         |   ✔     |   ✔     |         |
# | Launch Website                |        |        |        |        |        |        |        |        |        |         |         |         |         |   ✔    |
#
# ---
#
# This detailed task list and timeline ensure that every aspect of the website project is thoroughly planned, accounted for, and ready for execution. The deliverables allow for continuous tracking of progress and ensure stakeholder satisfaction upon completion.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Small Business Website Project
#
# #### Task Overview
#
# The following report outlines the estimated time, resources, and effort required for each task involved in the creation of a responsive website for a small business. It includes potential risks or uncertainties associated with the estimations.
#
# ---
#
# 1. **Create Wireframes & Mockups**
#    - **Estimated Time**: 40 hours
#    - **Resources**: 1 UX/UI Designer (Bob Smith)
#    - **Effort**: High due to the creative nature and need for approval.
#    - **Risks/Uncertainties**: Potential changes based on client feedback can extend time.
#
# 2. **Design the User Interface**
#    - **Estimated Time**: 80 hours
#    - **Resources**: 1 UX/UI Designer (Bob Smith)
#    - **Effort**: High due to the requirement for a polished and consistent look.
#    - **Risks/Uncertainties**: Complexity and scope creep might increase the workload.
#
# 3. **Develop Frontend Structure**
#    - **Estimated Time**: 120 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe)
#    - **Effort**: High as it involves coding and testing across devices.
#    - **Risks/Uncertainties**: Integration issues with design can lead to additional coding time.
#
# 4. **Implement Navigation System**
#    - **Estimated Time**: 40 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe)
#    - **Effort**: Medium, as it requires a balance of design and functionality.
#    - **Risks/Uncertainties**: Issues with user experience testing could necessitate redesigns.
#
# 5. **Develop "About Us" Page**
#    - **Estimated Time**: 30 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe)
#    - **Effort**: Low; mostly static content requiring review.
#    - **Risks/Uncertainties**: Content approval delays could impact timeline.
#
# 6. **Design "Services" Page**
#    - **Estimated Time**: 40 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe)
#    - **Effort**: Medium, needs comprehensive description input.
#    - **Risks/Uncertainties**: Changes in service descriptions may require last-minute adjustments.
#
# 7. **Create "Contact Us" Page**
#    - **Estimated Time**: 35 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe)
#    - **Effort**: Low; however, functionality for forms and map integration adds complexity.
#    - **Risks/Uncertainties**: Map integration might depend on external services.
#
# 8. **Implement Blog Section**
#    - **Estimated Time**: 50 hours
#    - **Resources**: 1 Frontend Developer (Jane Doe), 1 Content Writer (to create initial blog posts)
#    - **Effort**: Medium; includes setup and initial content creation.
#    - **Risks/Uncertainties**: Unclear posting frequency can lead to different setup requirements.
#
# 9. **Optimize for SEO and Speed**
#    - **Estimated Time**: 40 hours
#    - **Resources**: 1 SEO Specialist, 1 Frontend Developer (Jane Doe)
#    - **Effort**: High; requires thorough analysis and potential for lengthy adjustments.
#    - **Risks/Uncertainties**: Evolving SEO guidelines may demand ongoing updates.
#
# 10. **Integrate Social Media Links**
#     - **Estimated Time**: 20 hours
#     - **Resources**: 1 Frontend Developer (Jane Doe)
#     - **Effort**: Low; straightforward implementation.
#     - **Risks/Uncertainties**: Missing links or incorrect integration can occur.
#
# 11. **Add Testimonials Section**
#     - **Estimated Time**: 25 hours
#     - **Resources**: 1 Frontend Developer (Jane Doe)
#     - **Effort**: Medium; requires collection of testimonials.
#     - **Risks/Uncertainties**: Delays in obtaining customer feedback.
#
# 12. **Testing Phase**
#     - **Estimated Time**: 80 hours
#     - **Resources**: 2 Testers (Alice Johnson, Tom Brown)
#     - **Effort**: Very High; complexity increases with more content pages.
#     - **Risks/Uncertainties**: Unforeseen bugs can extend timelines.
#
# 13. **Launch Website**
#     - **Estimated Time**: 20 hours
#     - **Resources**: 1 Project Manager (John Doe)
#     - **Effort**: Low; mainly coordination and final checks.
#     - **Risks/Uncertainties**: Last-minute technical issues could delay the launch.
#
# ---
#
# ### Summary of Risks/Uncertainties:
# - Potential delays due to client feedback and content approval.
# - Integration of features may require adjustment periods due to various technologies.
# - Fluctuations in workload depending on task complexity.
# - Software and tools utilized may introduce variability in efficiency.
#
# ### Total Estimated Time:
# - **Estimated Time for All Tasks**: 535 hours
#
# This detailed estimation provides a structured overview of the expected resources, time, and associated risks for the website project. Adhering to these estimates will facilitate efficient progress and successful project completion.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for the Website Project
#
# | Task                              | Assigned Team Member(s)      | Start Date      | End Date        | Estimated Time |
# |-----------------------------------|-------------------------------|------------------|------------------|------------------|
# | Create Wireframes & Mockups       | Bob Smith (Designer)          | 01-Oct-2023      | 05-Oct-2023      | 40 hours         |
# | Design the User Interface          | Bob Smith (Designer)          | 06-Oct-2023      | 15-Oct-2023      | 80 hours         |
# | Develop Frontend Structure        | Jane Doe (Software Engineer)  | 16-Oct-2023      | 05-Nov-2023      | 120 hours        |
# | Implement Navigation System       | Jane Doe (Software Engineer)  | 06-Nov-2023      | 10-Nov-2023      | 40 hours         |
# | Develop "About Us" Page          | Jane Doe (Software Engineer)  | 11-Nov-2023      | 13-Nov-2023      | 30 hours         |
# | Design "Services" Page           | Jane Doe (Software Engineer)  | 14-Nov-2023      | 18-Nov-2023      | 40 hours         |
# | Create "Contact Us" Page         | Jane Doe (Software Engineer)  | 19-Nov-2023      | 22-Nov-2023      | 35 hours         |
# | Implement Blog Section            | Jane Doe (Software Engineer), (To be determined) | 23-Nov-2023      | 02-Dec-2023      | 50 hours         |
# | Optimize for SEO and Speed       | Jane Doe (Software Engineer)  | 03-Dec-2023      | 07-Dec-2023      | 40 hours         |
# | Integrate Social Media Links      | Jane Doe (Software Engineer)  | 08-Dec-2023      | 09-Dec-2023      | 20 hours         |
# | Add Testimonials Section          | Jane Doe (Software Engineer)  | 10-Dec-2023      | 12-Dec-2023      | 25 hours         |
# | Testing Phase                     | Alice Johnson, Tom Brown      | 13-Dec-2023      | 23-Dec-2023      | 80 hours         |
# | Launch Website                    | John Doe (Project Manager)    | 24-Dec-2023      | 24-Dec-2023      | 20 hours         |
#
# ### Summary of Allocation Decisions:
#
# 1. **Bob Smith (Designer)** is assigned the creative tasks (Create Wireframes & Mockups and Design the User Interface) as these require specialized design skills. Bob is allocated sufficient time for approvals and iterations based on likely client feedback.
#
# 2. **Jane Doe (Software Engineer)**, being versatile, is tasked with all frontend development tasks. The allocations are staggered to allow for bandwidth and project flow, including the bulk of coding and implementing the navigation, pages, and optimizing the site. This ensures consistent use of her development skills while balancing her workload across tasks.
#
# 3. **Alice Johnson and Tom Brown (QA Engineers)** are assigned to the testing phase because it requires focused testing efforts on the final product. Dividing the workload between them in this crucial phase ensures thorough testing without overburdening any individual.
#
# 4. **John Doe (Project Manager)** will oversee the launch, ensuring that all elements are coordinated for a successful rollout, capitalizing on his management skills to handle last-minute checks and troubleshooting.
#
# By balancing the allocation of tasks against individual skills, availability, and the overall workload, efficiency and effectiveness in achieving the project’s timeline goals are maximized while minimizing stress on team members. This strategic allocation encourages collaboration, maintains motivation, and ultimately drives successful project completion within the estimated timeline.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0029
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         19603          11964               7639                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Wireframes & Mockups',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Design the User Interface',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Develop Frontend Structure',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Develop "About Us" Page',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Design "Services" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 35.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 50.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Optimize for SEO and Speed',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Add Testimonials Section',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Testing Phase',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe (Project Manager)']}],
#  'milestones': [{'milestone_name': 'Design Phase Completion',
#    'tasks': ['Create Wireframes & Mockups', 'Design the User Interface']},
#   {'milestone_name': 'Development Phase Completion',
#    'tasks': ['Develop Frontend Structure',
#     'Implement Navigation System',
#     'Develop "About Us" Page',
#     'Design "Services" Page',
#     'Create "Contact Us" Page',
#     'Implement Blog Section',
#     'Optimize for SEO and Speed',
#     'Integrate Social Media Links',
#     'Add Testimonials Section']},
#   {'milestone_name': 'Testing Phase Completion', 'tasks': ['Testing Phase']},
#   {'milestone_name': 'Project Launch', 'tasks': ['Launch Website']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_29543 th {
#   font-size: 120%;
# }
# #T_29543  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_29543" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29543_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_29543_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_29543_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29543_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29543_row0_col0" class="data row0 col0" >Create Wireframes & Mockups</td>
#       <td id="T_29543_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_29543_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29543_row1_col0" class="data row1 col0" >Design the User Interface</td>
#       <td id="T_29543_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_29543_row1_col2" class="data row1 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29543_row2_col0" class="data row2 col0" >Develop Frontend Structure</td>
#       <td id="T_29543_row2_col1" class="data row2 col1" >120.000000</td>
#       <td id="T_29543_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29543_row3_col0" class="data row3 col0" >Implement Navigation System</td>
#       <td id="T_29543_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_29543_row3_col2" class="data row3 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29543_row4_col0" class="data row4 col0" >Develop "About Us" Page</td>
#       <td id="T_29543_row4_col1" class="data row4 col1" >30.000000</td>
#       <td id="T_29543_row4_col2" class="data row4 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29543_row5_col0" class="data row5 col0" >Design "Services" Page</td>
#       <td id="T_29543_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_29543_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29543_row6_col0" class="data row6 col0" >Create "Contact Us" Page</td>
#       <td id="T_29543_row6_col1" class="data row6 col1" >35.000000</td>
#       <td id="T_29543_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29543_row7_col0" class="data row7 col0" >Implement Blog Section</td>
#       <td id="T_29543_row7_col1" class="data row7 col1" >50.000000</td>
#       <td id="T_29543_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29543_row8_col0" class="data row8 col0" >Optimize for SEO and Speed</td>
#       <td id="T_29543_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_29543_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29543_row9_col0" class="data row9 col0" >Integrate Social Media Links</td>
#       <td id="T_29543_row9_col1" class="data row9 col1" >20.000000</td>
#       <td id="T_29543_row9_col2" class="data row9 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_29543_row10_col0" class="data row10 col0" >Add Testimonials Section</td>
#       <td id="T_29543_row10_col1" class="data row10 col1" >25.000000</td>
#       <td id="T_29543_row10_col2" class="data row10 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_29543_row11_col0" class="data row11 col0" >Testing Phase</td>
#       <td id="T_29543_row11_col1" class="data row11 col1" >80.000000</td>
#       <td id="T_29543_row11_col2" class="data row11 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_29543_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_29543_row12_col0" class="data row12 col0" >Launch Website</td>
#       <td id="T_29543_row12_col1" class="data row12 col1" >20.000000</td>
#       <td id="T_29543_row12_col2" class="data row12 col2" >['John Doe (Project Manager)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_7b047 th {
#   font-size: 120%;
# }
# #T_7b047  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_7b047" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b047_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_7b047_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b047_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b047_row0_col0" class="data row0 col0" >Design Phase Completion</td>
#       <td id="T_7b047_row0_col1" class="data row0 col1" >['Create Wireframes & Mockups', 'Design the User Interface']</td>
#     </tr>
#     <tr>
#       <th id="T_7b047_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b047_row1_col0" class="data row1 col0" >Development Phase Completion</td>
#       <td id="T_7b047_row1_col1" class="data row1 col1" >['Develop Frontend Structure', 'Implement Navigation System', 'Develop "About Us" Page', 'Design "Services" Page', 'Create "Contact Us" Page', 'Implement Blog Section', 'Optimize for SEO and Speed', 'Integrate Social Media Links', 'Add Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_7b047_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b047_row2_col0" class="data row2 col0" >Testing Phase Completion</td>
#       <td id="T_7b047_row2_col1" class="data row2 col1" >['Testing Phase']</td>
#     </tr>
#     <tr>
#       <th id="T_7b047_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b047_row3_col0" class="data row3 col0" >Project Launch</td>
#       <td id="T_7b047_row3_col1" class="data row3 col1" >['Launch Website']</td>
#     </tr>
#   </tbody>
# </table>
