# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
# 	Folder new_project already exists.
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Resolved 207 packages in 1.99s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------     0 B/349.71 KiB
# prompt-toolkit ------------------------------     0 B/378.72 KiB
# pydantic   ------------------------------     0 B/433.50 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/470.15 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 46.92 KiB/349.71 KiB
# langsmith  ------------------------------ 30.92 KiB/351.69 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.72 KiB
# rpds-py    ------------------------------ 16.00 KiB/380.31 KiB
# langchain-core ------------------------------     0 B/427.29 KiB
# pydantic   ------------------------------ 30.78 KiB/433.50 KiB
# watchfiles ------------------------------ 30.91 KiB/444.09 KiB
# httptools  ------------------------------ 30.91 KiB/449.01 KiB
# cffi       ------------------------------ 46.88 KiB/456.29 KiB
# huggingface-hub ------------------------------ 30.88 KiB/470.15 KiB
# pytz       ------------------------------ 16.00 KiB/496.10 KiB
# mpmath     ------------------------------ 76.68 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/570.24 KiB
# crewai-tools ------------------------------ 16.00 KiB/570.25 KiB
# chromadb   ------------------------------ 16.00 KiB/613.62 KiB
# openai     ------------------------------ 30.89 KiB/646.51 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 16.00 KiB/774.15 KiB
# ipython    ------------------------------ 16.00 KiB/811.60 KiB
# langchain  ------------------------------ 30.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 190.14 KiB/349.71 KiB
# langsmith  ------------------------------ 46.92 KiB/351.69 KiB
# prompt-toolkit ------------------------------ 46.77 KiB/378.72 KiB
# rpds-py    ------------------------------ 191.71 KiB/380.31 KiB
# langchain-core ------------------------------ 14.88 KiB/427.29 KiB
# pydantic   ------------------------------ 62.78 KiB/433.50 KiB
# watchfiles ------------------------------ 190.91 KiB/444.09 KiB
# httptools  ------------------------------ 190.91 KiB/449.01 KiB
# cffi       ------------------------------ 200.58 KiB/456.29 KiB
# huggingface-hub ------------------------------ 62.88 KiB/470.15 KiB
# pytz       ------------------------------ 32.00 KiB/496.10 KiB
# mpmath     ------------------------------ 136.81 KiB/523.63 KiB
# greenlet   ------------------------------ 32.00 KiB/570.24 KiB
# crewai-tools ------------------------------ 16.00 KiB/570.25 KiB
# chromadb   ------------------------------ 31.89 KiB/613.62 KiB
# openai     ------------------------------ 46.89 KiB/646.51 KiB
# pyvis      ------------------------------ 206.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# regex      ------------------------------ 164.84 KiB/774.15 KiB
# ipython    ------------------------------ 32.00 KiB/811.60 KiB
# langchain  ------------------------------ 30.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 254.25 KiB/349.71 KiB
# langsmith  ------------------------------ 126.92 KiB/351.69 KiB
# prompt-toolkit ------------------------------ 79.81 KiB/378.72 KiB
# rpds-py    ------------------------------ 255.71 KiB/380.31 KiB
# langchain-core ------------------------------ 30.88 KiB/427.29 KiB
# pydantic   ------------------------------ 158.73 KiB/433.50 KiB
# watchfiles ------------------------------ 238.09 KiB/444.09 KiB
# httptools  ------------------------------ 253.98 KiB/449.01 KiB
# cffi       ------------------------------ 268.97 KiB/456.29 KiB
# huggingface-hub ------------------------------ 219.68 KiB/470.15 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# mpmath     ------------------------------ 204.68 KiB/523.63 KiB
# greenlet   ------------------------------ 238.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 32.00 KiB/570.25 KiB
# chromadb   ------------------------------ 63.79 KiB/613.62 KiB
# openai     ------------------------------ 62.89 KiB/646.51 KiB
# pyvis      ------------------------------ 270.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 267.41 KiB/745.07 KiB
# regex      ------------------------------ 222.60 KiB/774.15 KiB
# ipython    ------------------------------ 109.68 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/200)
# yarl       ------------------------------ 328.83 KiB/349.71 KiB
# langsmith  ------------------------------ 318.92 KiB/351.69 KiB
# prompt-toolkit ------------------------------ 95.81 KiB/378.72 KiB
# rpds-py    ------------------------------ 335.71 KiB/380.31 KiB
# langchain-core ------------------------------ 62.88 KiB/427.29 KiB
# pydantic   ------------------------------ 190.73 KiB/433.50 KiB
# watchfiles ------------------------------ 333.98 KiB/444.09 KiB
# httptools  ------------------------------ 333.98 KiB/449.01 KiB
# cffi       ------------------------------ 342.33 KiB/456.29 KiB
# huggingface-hub ------------------------------ 251.68 KiB/470.15 KiB
# pytz       ------------------------------ 48.00 KiB/496.10 KiB
# mpmath     ------------------------------ 300.68 KiB/523.63 KiB
# greenlet   ------------------------------ 334.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 32.00 KiB/570.25 KiB
# chromadb   ------------------------------ 80.00 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/646.51 KiB
# pyvis      ------------------------------ 348.33 KiB/738.32 KiB
# pyyaml     ------------------------------ 335.41 KiB/745.07 KiB
# regex      ------------------------------ 299.38 KiB/774.15 KiB
# ipython    ------------------------------ 203.44 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# yarl       ------------------------------ 349.71 KiB/349.71 KiB
# prompt-toolkit ------------------------------ 111.81 KiB/378.72 KiB
# rpds-py    ------------------------------ 380.31 KiB/380.31 KiB
# langchain-core ------------------------------ 62.88 KiB/427.29 KiB
# pydantic   ------------------------------ 254.73 KiB/433.50 KiB
# watchfiles ------------------------------ 369.46 KiB/444.09 KiB
# httptools  ------------------------------ 382.09 KiB/449.01 KiB
# cffi       ------------------------------ 386.31 KiB/456.29 KiB
# huggingface-hub ------------------------------ 329.39 KiB/470.15 KiB
# pytz       ------------------------------ 63.48 KiB/496.10 KiB
# mpmath     ------------------------------ 380.68 KiB/523.63 KiB
# greenlet   ------------------------------ 382.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 48.00 KiB/570.25 KiB
# chromadb   ------------------------------ 112.00 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/646.51 KiB
# pyvis      ------------------------------ 396.33 KiB/738.32 KiB
# pyyaml     ------------------------------ 399.41 KiB/745.07 KiB
# regex      ------------------------------ 350.60 KiB/774.15 KiB
# ipython    ------------------------------ 251.44 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 350.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# prompt-toolkit ------------------------------ 111.81 KiB/378.72 KiB
# rpds-py    ------------------------------ 380.31 KiB/380.31 KiB
# langchain-core ------------------------------ 62.88 KiB/427.29 KiB
# pydantic   ------------------------------ 254.73 KiB/433.50 KiB
# watchfiles ------------------------------ 369.46 KiB/444.09 KiB
# httptools  ------------------------------ 382.09 KiB/449.01 KiB
# cffi       ------------------------------ 386.31 KiB/456.29 KiB
# huggingface-hub ------------------------------ 329.39 KiB/470.15 KiB
# pytz       ------------------------------ 63.48 KiB/496.10 KiB
# mpmath     ------------------------------ 380.68 KiB/523.63 KiB
# greenlet   ------------------------------ 382.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 48.00 KiB/570.25 KiB
# chromadb   ------------------------------ 112.00 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/646.51 KiB
# pyvis      ------------------------------ 396.33 KiB/738.32 KiB
# pyyaml     ------------------------------ 399.41 KiB/745.07 KiB
# regex      ------------------------------ 350.60 KiB/774.15 KiB
# ipython    ------------------------------ 251.44 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 350.88 KiB/1.14 MiB
# pygments   ------------------------------ 335.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# prompt-toolkit ------------------------------ 127.81 KiB/378.72 KiB
# langchain-core ------------------------------ 62.88 KiB/427.29 KiB
# pydantic   ------------------------------ 254.73 KiB/433.50 KiB
# watchfiles ------------------------------ 369.46 KiB/444.09 KiB
# httptools  ------------------------------ 382.09 KiB/449.01 KiB
# cffi       ------------------------------ 386.31 KiB/456.29 KiB
# huggingface-hub ------------------------------ 329.39 KiB/470.15 KiB
# pytz       ------------------------------ 63.48 KiB/496.10 KiB
# mpmath     ------------------------------ 383.96 KiB/523.63 KiB
# greenlet   ------------------------------ 382.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 48.00 KiB/570.25 KiB
# chromadb   ------------------------------ 112.00 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/646.51 KiB
# pyvis      ------------------------------ 398.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 399.41 KiB/745.07 KiB
# regex      ------------------------------ 350.60 KiB/774.15 KiB
# ipython    ------------------------------ 269.79 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 350.88 KiB/1.14 MiB
# pygments   ------------------------------ 351.12 KiB/1.17 MiB
# jedi       ------------------------------ 173.98 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# prompt-toolkit ------------------------------ 127.81 KiB/378.72 KiB
# langchain-core ------------------------------ 78.88 KiB/427.29 KiB
# pydantic   ------------------------------ 270.73 KiB/433.50 KiB
# watchfiles ------------------------------ 369.46 KiB/444.09 KiB
# httptools  ------------------------------ 398.09 KiB/449.01 KiB
# cffi       ------------------------------ 386.31 KiB/456.29 KiB
# huggingface-hub ------------------------------ 329.39 KiB/470.15 KiB
# pytz       ------------------------------ 107.72 KiB/496.10 KiB
# mpmath     ------------------------------ 396.68 KiB/523.63 KiB
# greenlet   ------------------------------ 398.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 64.00 KiB/570.25 KiB
# chromadb   ------------------------------ 367.99 KiB/613.62 KiB
# openai     ------------------------------ 78.89 KiB/646.51 KiB
# pyvis      ------------------------------ 414.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 412.15 KiB/745.07 KiB
# regex      ------------------------------ 366.49 KiB/774.15 KiB
# ipython    ------------------------------ 285.68 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 366.88 KiB/1.14 MiB
# pygments   ------------------------------ 351.12 KiB/1.17 MiB
# jedi       ------------------------------ 173.98 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 48.00 KiB/320.01 KiB
# jiter      ------------------------------ 62.67 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 143.81 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/427.29 KiB
# pydantic   ------------------------------ 302.73 KiB/433.50 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 347.68 KiB/470.15 KiB
# pytz       ------------------------------ 107.72 KiB/496.10 KiB
# mpmath     ------------------------------ 428.68 KiB/523.63 KiB
# greenlet   ------------------------------ 462.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 64.00 KiB/570.25 KiB
# chromadb   ------------------------------ 367.99 KiB/613.62 KiB
# openai     ------------------------------ 114.22 KiB/646.51 KiB
# pyvis      ------------------------------ 462.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 479.41 KiB/745.07 KiB
# regex      ------------------------------ 414.60 KiB/774.15 KiB
# ipython    ------------------------------ 349.79 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 440.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 48.00 KiB/320.01 KiB
# jiter      ------------------------------ 64.00 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 143.81 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/427.29 KiB
# pydantic   ------------------------------ 302.73 KiB/433.50 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 347.68 KiB/470.15 KiB
# pytz       ------------------------------ 107.72 KiB/496.10 KiB
# mpmath     ------------------------------ 428.68 KiB/523.63 KiB
# greenlet   ------------------------------ 462.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 64.00 KiB/570.25 KiB
# chromadb   ------------------------------ 367.99 KiB/613.62 KiB
# openai     ------------------------------ 114.22 KiB/646.51 KiB
# pyvis      ------------------------------ 478.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 479.41 KiB/745.07 KiB
# regex      ------------------------------ 421.34 KiB/774.15 KiB
# ipython    ------------------------------ 349.79 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 456.56 KiB/1.14 MiB
# pygments   ------------------------------ 399.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# qdrant-client ------------------------------ 48.00 KiB/320.01 KiB
# jiter      ------------------------------ 80.00 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 143.81 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/427.29 KiB
# pydantic   ------------------------------ 302.73 KiB/433.50 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 347.68 KiB/470.15 KiB
# pytz       ------------------------------ 107.72 KiB/496.10 KiB
# mpmath     ------------------------------ 476.68 KiB/523.63 KiB
# greenlet   ------------------------------ 462.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 80.00 KiB/570.25 KiB
# chromadb   ------------------------------ 367.99 KiB/613.62 KiB
# openai     ------------------------------ 114.22 KiB/646.51 KiB
# pyvis      ------------------------------ 494.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 480.77 KiB/745.07 KiB
# regex      ------------------------------ 437.34 KiB/774.15 KiB
# ipython    ------------------------------ 365.79 KiB/811.60 KiB
# langchain  ------------------------------ 46.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 456.56 KiB/1.14 MiB
# pygments   ------------------------------ 399.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# frozenlist ------------------------------     0 B/306.27 KiB
# protobuf   ------------------------------     0 B/312.18 KiB
# qdrant-client ------------------------------ 48.00 KiB/320.01 KiB
# jiter      ------------------------------ 80.00 KiB/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 159.81 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/427.29 KiB
# pydantic   ------------------------------ 318.73 KiB/433.50 KiB
# huggingface-hub ------------------------------ 347.68 KiB/470.15 KiB
# pytz       ------------------------------ 107.72 KiB/496.10 KiB
# mpmath     ------------------------------ 492.68 KiB/523.63 KiB
# greenlet   ------------------------------ 462.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 80.00 KiB/570.25 KiB
# chromadb   ------------------------------ 367.99 KiB/613.62 KiB
# openai     ------------------------------ 114.22 KiB/646.51 KiB
# pyvis      ------------------------------ 510.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 496.77 KiB/745.07 KiB
# regex      ------------------------------ 453.34 KiB/774.15 KiB
# ipython    ------------------------------ 365.79 KiB/811.60 KiB
# langchain  ------------------------------ 62.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 472.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# crewai     ------------------------------ 32.00 KiB/298.01 KiB
# frozenlist ------------------------------ 61.28 KiB/306.27 KiB
# protobuf   ------------------------------ 60.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 128.00 KiB/320.01 KiB
# jiter      ------------------------------ 144.00 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 207.81 KiB/378.72 KiB
# langchain-core ------------------------------ 174.88 KiB/427.29 KiB
# pydantic   ------------------------------ 414.73 KiB/433.50 KiB
# huggingface-hub ------------------------------ 379.68 KiB/470.15 KiB
# pytz       ------------------------------ 123.72 KiB/496.10 KiB
# greenlet   ------------------------------ 494.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 127.89 KiB/570.25 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# openai     ------------------------------ 158.89 KiB/646.51 KiB
# pyvis      ------------------------------ 558.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 553.85 KiB/745.07 KiB
# regex      ------------------------------ 510.49 KiB/774.15 KiB
# ipython    ------------------------------ 397.79 KiB/811.60 KiB
# langchain  ------------------------------ 62.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 536.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# crewai     ------------------------------ 48.00 KiB/298.01 KiB
# frozenlist ------------------------------ 61.28 KiB/306.27 KiB
# protobuf   ------------------------------ 60.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# jiter      ------------------------------ 160.00 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 223.81 KiB/378.72 KiB
# langchain-core ------------------------------ 174.88 KiB/427.29 KiB
# pydantic   ------------------------------ 430.73 KiB/433.50 KiB
# huggingface-hub ------------------------------ 395.68 KiB/470.15 KiB
# pytz       ------------------------------ 123.72 KiB/496.10 KiB
# greenlet   ------------------------------ 494.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 127.89 KiB/570.25 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# openai     ------------------------------ 158.89 KiB/646.51 KiB
# pyvis      ------------------------------ 558.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 553.85 KiB/745.07 KiB
# regex      ------------------------------ 510.49 KiB/774.15 KiB
# ipython    ------------------------------ 397.79 KiB/811.60 KiB
# langchain  ------------------------------ 78.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 552.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# crewai     ------------------------------ 48.00 KiB/298.01 KiB
# frozenlist ------------------------------ 77.28 KiB/306.27 KiB
# protobuf   ------------------------------ 76.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 144.00 KiB/320.01 KiB
# jiter      ------------------------------ 160.00 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 223.81 KiB/378.72 KiB
# langchain-core ------------------------------ 190.88 KiB/427.29 KiB
# huggingface-hub ------------------------------ 395.68 KiB/470.15 KiB
# pytz       ------------------------------ 123.72 KiB/496.10 KiB
# greenlet   ------------------------------ 494.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 127.89 KiB/570.25 KiB
# chromadb   ------------------------------ 416.00 KiB/613.62 KiB
# openai     ------------------------------ 158.89 KiB/646.51 KiB
# pyvis      ------------------------------ 574.02 KiB/738.32 KiB
# pyyaml     ------------------------------ 569.85 KiB/745.07 KiB
# regex      ------------------------------ 526.49 KiB/774.15 KiB
# ipython    ------------------------------ 413.79 KiB/811.60 KiB
# langchain  ------------------------------ 78.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 552.56 KiB/1.14 MiB
# pygments   ------------------------------ 511.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/200)
# googleapis-common-protos ------------------------------ 30.87 KiB/287.63 KiB
# pypdf      ------------------------------ 62.45 KiB/295.22 KiB
# crewai     ------------------------------ 75.47 KiB/298.01 KiB
# frozenlist ------------------------------ 157.28 KiB/306.27 KiB
# protobuf   ------------------------------ 156.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 192.00 KiB/320.01 KiB
# jiter      ------------------------------ 253.33 KiB/337.45 KiB
# tzdata     ------------------------------ 77.32 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 287.81 KiB/378.72 KiB
# langchain-core ------------------------------ 270.88 KiB/427.29 KiB
# huggingface-hub ------------------------------ 447.68 KiB/470.15 KiB
# pytz       ------------------------------ 123.72 KiB/496.10 KiB
# greenlet   ------------------------------ 558.55 KiB/570.24 KiB
# crewai-tools ------------------------------ 496.00 KiB/570.25 KiB
# chromadb   ------------------------------ 447.89 KiB/613.62 KiB
# openai     ------------------------------ 222.89 KiB/646.51 KiB
# pyvis      ------------------------------ 637.92 KiB/738.32 KiB
# pyyaml     ------------------------------ 639.41 KiB/745.07 KiB
# regex      ------------------------------ 579.94 KiB/774.15 KiB
# ipython    ------------------------------ 461.79 KiB/811.60 KiB
# langchain  ------------------------------ 94.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# googleapis-common-protos ------------------------------ 46.87 KiB/287.63 KiB
# pypdf      ------------------------------ 94.45 KiB/295.22 KiB
# crewai     ------------------------------ 83.52 KiB/298.01 KiB
# frozenlist ------------------------------ 205.28 KiB/306.27 KiB
# protobuf   ------------------------------ 188.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 224.00 KiB/320.01 KiB
# jiter      ------------------------------ 272.00 KiB/337.45 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 335.81 KiB/378.72 KiB
# langchain-core ------------------------------ 302.88 KiB/427.29 KiB
# pytz       ------------------------------ 143.48 KiB/496.10 KiB
# greenlet   ------------------------------ 570.24 KiB/570.24 KiB
# crewai-tools ------------------------------ 510.89 KiB/570.25 KiB
# chromadb   ------------------------------ 470.99 KiB/613.62 KiB
# openai     ------------------------------ 238.89 KiB/646.51 KiB
# pyvis      ------------------------------ 656.11 KiB/738.32 KiB
# pyyaml     ------------------------------ 687.41 KiB/745.07 KiB
# regex      ------------------------------ 606.60 KiB/774.15 KiB
# ipython    ------------------------------ 477.79 KiB/811.60 KiB
# langchain  ------------------------------ 110.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# googleapis-common-protos ------------------------------ 46.87 KiB/287.63 KiB
# pypdf      ------------------------------ 94.45 KiB/295.22 KiB
# crewai     ------------------------------ 83.52 KiB/298.01 KiB
# frozenlist ------------------------------ 205.28 KiB/306.27 KiB
# protobuf   ------------------------------ 188.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 224.00 KiB/320.01 KiB
# jiter      ------------------------------ 272.00 KiB/337.45 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 335.81 KiB/378.72 KiB
# langchain-core ------------------------------ 302.88 KiB/427.29 KiB
# pytz       ------------------------------ 143.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 510.89 KiB/570.25 KiB
# chromadb   ------------------------------ 470.99 KiB/613.62 KiB
# openai     ------------------------------ 238.89 KiB/646.51 KiB
# pyvis      ------------------------------ 656.11 KiB/738.32 KiB
# pyyaml     ------------------------------ 687.41 KiB/745.07 KiB
# regex      ------------------------------ 606.60 KiB/774.15 KiB
# ipython    ------------------------------ 493.79 KiB/811.60 KiB
# langchain  ------------------------------ 110.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.14 MiB
# pygments   ------------------------------ 607.02 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# cohere     ------------------------------ 16.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 62.87 KiB/287.63 KiB
# pypdf      ------------------------------ 126.45 KiB/295.22 KiB
# crewai     ------------------------------ 99.52 KiB/298.01 KiB
# frozenlist ------------------------------ 224.65 KiB/306.27 KiB
# protobuf   ------------------------------ 220.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 240.00 KiB/320.01 KiB
# jiter      ------------------------------ 303.89 KiB/337.45 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# prompt-toolkit ------------------------------ 367.81 KiB/378.72 KiB
# langchain-core ------------------------------ 326.68 KiB/427.29 KiB
# pytz       ------------------------------ 143.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 524.36 KiB/570.25 KiB
# chromadb   ------------------------------ 470.99 KiB/613.62 KiB
# openai     ------------------------------ 254.89 KiB/646.51 KiB
# pyvis      ------------------------------ 688.11 KiB/738.32 KiB
# pyyaml     ------------------------------ 719.41 KiB/745.07 KiB
# regex      ------------------------------ 654.60 KiB/774.15 KiB
# ipython    ------------------------------ 541.79 KiB/811.60 KiB
# langchain  ------------------------------ 110.88 KiB/987.31 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# cohere     ------------------------------ 32.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 75.55 KiB/287.63 KiB
# pypdf      ------------------------------ 148.81 KiB/295.22 KiB
# crewai     ------------------------------ 99.52 KiB/298.01 KiB
# frozenlist ------------------------------ 240.65 KiB/306.27 KiB
# protobuf   ------------------------------ 236.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 256.00 KiB/320.01 KiB
# jiter      ------------------------------ 320.00 KiB/337.45 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 350.88 KiB/427.29 KiB
# pytz       ------------------------------ 143.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 524.36 KiB/570.25 KiB
# chromadb   ------------------------------ 486.99 KiB/613.62 KiB
# openai     ------------------------------ 270.89 KiB/646.51 KiB
# pyvis      ------------------------------ 708.88 KiB/738.32 KiB
# pyyaml     ------------------------------ 745.07 KiB/745.07 KiB
# regex      ------------------------------ 686.60 KiB/774.15 KiB
# ipython    ------------------------------ 573.79 KiB/811.60 KiB
# langchain  ------------------------------ 126.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 728.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# cohere     ------------------------------ 48.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 32.12 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 75.55 KiB/287.63 KiB
# pypdf      ------------------------------ 155.65 KiB/295.22 KiB
# crewai     ------------------------------ 99.52 KiB/298.01 KiB
# frozenlist ------------------------------ 253.28 KiB/306.27 KiB
# protobuf   ------------------------------ 252.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 256.00 KiB/320.01 KiB
# jiter      ------------------------------ 336.00 KiB/337.45 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 366.88 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.36 KiB/570.25 KiB
# chromadb   ------------------------------ 486.99 KiB/613.62 KiB
# openai     ------------------------------ 270.89 KiB/646.51 KiB
# pyvis      ------------------------------ 718.02 KiB/738.32 KiB
# regex      ------------------------------ 686.60 KiB/774.15 KiB
# ipython    ------------------------------ 589.79 KiB/811.60 KiB
# langchain  ------------------------------ 126.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 744.56 KiB/1.14 MiB
# pygments   ------------------------------ 687.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# rich       ------------------------------     0 B/236.74 KiB
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------ 48.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 61.36 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 91.55 KiB/287.63 KiB
# pypdf      ------------------------------ 187.65 KiB/295.22 KiB
# crewai     ------------------------------ 99.52 KiB/298.01 KiB
# frozenlist ------------------------------ 285.28 KiB/306.27 KiB
# protobuf   ------------------------------ 252.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 272.00 KiB/320.01 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 366.88 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.36 KiB/570.25 KiB
# chromadb   ------------------------------ 486.99 KiB/613.62 KiB
# openai     ------------------------------ 270.89 KiB/646.51 KiB
# pyvis      ------------------------------ 734.02 KiB/738.32 KiB
# regex      ------------------------------ 718.60 KiB/774.15 KiB
# ipython    ------------------------------ 605.79 KiB/811.60 KiB
# langchain  ------------------------------ 126.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 760.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# cohere     ------------------------------ 64.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 62.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 91.55 KiB/287.63 KiB
# pypdf      ------------------------------ 190.45 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# frozenlist ------------------------------ 301.28 KiB/306.27 KiB
# protobuf   ------------------------------ 268.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 304.00 KiB/320.01 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 382.88 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.36 KiB/570.25 KiB
# chromadb   ------------------------------ 486.99 KiB/613.62 KiB
# openai     ------------------------------ 270.89 KiB/646.51 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# regex      ------------------------------ 734.60 KiB/774.15 KiB
# ipython    ------------------------------ 621.79 KiB/811.60 KiB
# langchain  ------------------------------ 142.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 792.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# cohere     ------------------------------ 64.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 78.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 91.55 KiB/287.63 KiB
# pypdf      ------------------------------ 190.45 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# frozenlist ------------------------------ 301.28 KiB/306.27 KiB
# protobuf   ------------------------------ 268.47 KiB/312.18 KiB
# qdrant-client ------------------------------ 304.00 KiB/320.01 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 382.88 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 540.36 KiB/570.25 KiB
# chromadb   ------------------------------ 486.99 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/646.51 KiB
# regex      ------------------------------ 750.60 KiB/774.15 KiB
# ipython    ------------------------------ 621.79 KiB/811.60 KiB
# langchain  ------------------------------ 142.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 792.56 KiB/1.14 MiB
# pygments   ------------------------------ 767.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# tomli      ------------------------------     0 B/230.50 KiB
# rich       ------------------------------ 32.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# cohere     ------------------------------ 64.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 78.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 107.55 KiB/287.63 KiB
# pypdf      ------------------------------ 193.41 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# frozenlist ------------------------------ 306.27 KiB/306.27 KiB
# protobuf   ------------------------------ 284.47 KiB/312.18 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 392.56 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 556.36 KiB/570.25 KiB
# chromadb   ------------------------------ 502.99 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/646.51 KiB
# regex      ------------------------------ 766.60 KiB/774.15 KiB
# ipython    ------------------------------ 637.79 KiB/811.60 KiB
# langchain  ------------------------------ 142.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 808.56 KiB/1.14 MiB
# pygments   ------------------------------ 783.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# propcache  ------------------------------     0 B/227.05 KiB
# tomli      ------------------------------ 1.03 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# cohere     ------------------------------ 64.00 KiB/253.44 KiB
# bcrypt     ------------------------------ 94.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 107.55 KiB/287.63 KiB
# pypdf      ------------------------------ 209.41 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# protobuf   ------------------------------ 284.47 KiB/312.18 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 392.56 KiB/427.29 KiB
# pytz       ------------------------------ 159.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 556.36 KiB/570.25 KiB
# chromadb   ------------------------------ 502.99 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/646.51 KiB
# regex      ------------------------------ 766.60 KiB/774.15 KiB
# ipython    ------------------------------ 637.79 KiB/811.60 KiB
# langchain  ------------------------------ 142.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 824.56 KiB/1.14 MiB
# pygments   ------------------------------ 783.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# propcache  ------------------------------     0 B/227.05 KiB
# tomli      ------------------------------ 4.49 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 18.99 KiB/245.03 KiB
# cohere     ------------------------------ 79.89 KiB/253.44 KiB
# bcrypt     ------------------------------ 110.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 107.55 KiB/287.63 KiB
# pypdf      ------------------------------ 225.41 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# protobuf   ------------------------------ 300.47 KiB/312.18 KiB
# tzdata     ------------------------------ 93.63 KiB/339.69 KiB
# langchain-core ------------------------------ 408.56 KiB/427.29 KiB
# pytz       ------------------------------ 175.48 KiB/496.10 KiB
# crewai-tools ------------------------------ 556.36 KiB/570.25 KiB
# chromadb   ------------------------------ 502.99 KiB/613.62 KiB
# openai     ------------------------------ 286.89 KiB/646.51 KiB
# ipython    ------------------------------ 637.79 KiB/811.60 KiB
# langchain  ------------------------------ 142.88 KiB/987.31 KiB
# tiktoken   ------------------------------ 824.56 KiB/1.14 MiB
# pygments   ------------------------------ 799.12 KiB/1.17 MiB
# jedi       ------------------------------ 269.98 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (8/200)
# alembic    ------------------------------     0 B/226.48 KiB
# propcache  ------------------------------ 16.00 KiB/227.05 KiB
# tomli      ------------------------------ 4.49 KiB/230.50 KiB
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# openpyxl   ------------------------------ 18.99 KiB/245.03 KiB
# cohere     ------------------------------ 79.89 KiB/253.44 KiB
# bcrypt     ------------------------------ 110.25 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 123.16 KiB/287.63 KiB
# pypdf      ------------------------------ 225.41 KiB/295.22 KiB
# crewai     ------------------------------ 115.52 KiB/298.01 KiB
# ...
# numpy      ------------------------------ 8.85 MiB/15.67 MiB
# uv         ------------------------------ 12.85 MiB/16.57 MiB
# lancedb    ------------------------------ 13.22 MiB/32.22 MiB
# ⠼ Preparing packages... (194/200) 13.81 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 13.81 MiB/15.26 MiB
# numpy      ------------------------------ 8.85 MiB/15.67 MiB
# uv         ------------------------------ 12.85 MiB/16.57 MiB
# lancedb    ------------------------------ 13.22 MiB/32.22 MiB
# ⠼ Preparing packages... (194/200) 13.83 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 8.85 MiB/15.67 MiB
# uv         ------------------------------ 13.92 MiB/16.57 MiB
# lancedb    ------------------------------ 14.14 MiB/32.22 MiB
# ⠴ Preparing packages... (194/200) 14.50 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 10.44 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 15.12 MiB/32.22 MiB
# ⠴ Preparing packages... (194/200) 15.30 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 10.46 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 15.12 MiB/32.22 MiB
# ⠴ Preparing packages... (194/200) 15.30 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 10.48 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 15.12 MiB/32.22 MiB
# ⠦ Preparing packages... (194/200) 15.30 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 11.83 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 15.12 MiB/32.22 MiB
# ⠦ Preparing packages... (194/200) 15.30 MiB/40.34 MiB
# pyright    ------------------------------ 2.97 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.49 MiB/15.26 MiB
# numpy      ------------------------------ 11.83 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 15.12 MiB/32.22 MiB
# ⠦ Preparing packages... (194/200) 15.30 MiB/40.34 MiB
# pyright    ------------------------------ 2.99 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.60 MiB/15.26 MiB
# numpy      ------------------------------ 12.47 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 16.58 MiB/32.22 MiB
# ⠦ Preparing packages... (194/200) 17.01 MiB/40.34 MiB
# pyright    ------------------------------ 2.99 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.63 MiB/15.26 MiB
# numpy      ------------------------------ 13.92 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 17.97 MiB/32.22 MiB
# ⠦ Preparing packages... (194/200) 18.32 MiB/40.34 MiB
# pyright    ------------------------------ 3.01 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.63 MiB/15.26 MiB
# numpy      ------------------------------ 15.26 MiB/15.67 MiB
# uv         ------------------------------ 14.99 MiB/16.57 MiB
# lancedb    ------------------------------ 19.56 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 19.54 MiB/40.34 MiB
# pyright    ------------------------------ 3.01 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# numpy      ------------------------------ 15.61 MiB/15.67 MiB
# uv         ------------------------------ 15.14 MiB/16.57 MiB
# lancedb    ------------------------------ 21.38 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 21.34 MiB/40.34 MiB
# pyright    ------------------------------ 3.01 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# numpy      ------------------------------ 15.64 MiB/15.67 MiB
# uv         ------------------------------ 16.56 MiB/16.57 MiB
# lancedb    ------------------------------ 22.70 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 22.89 MiB/40.34 MiB
# pyright    ------------------------------ 3.01 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# numpy      ------------------------------ 15.65 MiB/15.67 MiB
# lancedb    ------------------------------ 23.48 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 23.58 MiB/40.34 MiB
# pyright    ------------------------------ 3.02 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.66 MiB/15.26 MiB
# numpy      ------------------------------ 15.65 MiB/15.67 MiB
# lancedb    ------------------------------ 23.99 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 25.64 MiB/40.34 MiB
# pyright    ------------------------------ 3.02 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.66 MiB/15.26 MiB
# lancedb    ------------------------------ 24.74 MiB/32.22 MiB
# ⠧ Preparing packages... (194/200) 26.53 MiB/40.34 MiB
# pyright    ------------------------------ 3.05 MiB/5.31 MiB
# onnxruntime ------------------------------ 14.77 MiB/15.26 MiB
# lancedb    ------------------------------ 25.73 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.05 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# lancedb    ------------------------------ 26.67 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.05 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# lancedb    ------------------------------ 26.72 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.05 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# lancedb    ------------------------------ 26.73 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.05 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# lancedb    ------------------------------ 26.75 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# lancedb    ------------------------------ 28.39 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 27.91 MiB/40.34 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.19 MiB/15.26 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠋ Preparing packages... (196/200) 28.02 MiB/40.34 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.19 MiB/15.26 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠙ Preparing packages... (196/200) 28.03 MiB/40.34 MiB
# pyright    ------------------------------ 3.07 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.19 MiB/15.26 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠙ Preparing packages... (196/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.13 MiB/5.31 MiB
# onnxruntime ------------------------------ 15.19 MiB/15.26 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠙ Preparing packages... (196/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.22 MiB/5.31 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠙ Preparing packages... (196/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.34 MiB/5.31 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠙ Preparing packages... (196/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.69 MiB/5.31 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠹ Preparing packages... (197/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.81 MiB/5.31 MiB
# lancedb    ------------------------------ 29.36 MiB/32.22 MiB
# ⠹ Preparing packages... (197/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.81 MiB/5.31 MiB
# lancedb    ------------------------------ 29.44 MiB/32.22 MiB
# ⠹ Preparing packages... (197/200) 29.11 MiB/40.34 MiB
# pyright    ------------------------------ 3.83 MiB/5.31 MiB
# lancedb    ------------------------------ 30.47 MiB/32.22 MiB
# ⠹ Preparing packages... (197/200) 29.47 MiB/40.34 MiB
# pyright    ------------------------------ 3.84 MiB/5.31 MiB
# lancedb    ------------------------------ 30.47 MiB/32.22 MiB
# ⠹ Preparing packages... (197/200) 29.47 MiB/40.34 MiB
# pyright    ------------------------------ 4.12 MiB/5.31 MiB
# lancedb    ------------------------------ 30.47 MiB/32.22 MiB
# ⠸ Preparing packages... (197/200) 29.47 MiB/40.34 MiB
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# lancedb    ------------------------------ 30.55 MiB/32.22 MiB
# ⠸ Preparing packages... (197/200) 29.47 MiB/40.34 MiB
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# ⠸ Preparing packages... (197/200) 29.47 MiB/40.34 MiB
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# ⠸ Preparing packages... (197/200) 29.58 MiB/40.34 MiB
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# ⠼ Preparing packages... (198/200) 33.31 MiB/40.34 MiB
# pyright    ------------------------------ 4.20 MiB/5.31 MiB
# ⠼ Preparing packages... (198/200) 36.16 MiB/40.34 MiB
# pyright    ------------------------------ 4.45 MiB/5.31 MiB
# ⠼ Preparing packages... (198/200) 36.16 MiB/40.34 MiB
# pyright    ------------------------------ 4.79 MiB/5.31 MiB
# ⠼ Preparing packages... (198/200) 37.33 MiB/40.34 MiB
# ⠼ Preparing packages... (198/200) 37.33 MiB/40.34 MiB
# ⠴ Preparing packages... (199/200) 37.40 MiB/40.34 MiB
# ⠴ Preparing packages... (199/200) 38.23 MiB/40.34 MiB
# ⠴ Preparing packages... (199/200) 38.27 MiB/40.34 MiB
# ⠴ Preparing packages... (199/200) 38.28 MiB/40.34 MiB
# ⠴ Preparing packages... (199/200) 38.30 MiB/40.34 MiB
# ⠦ Preparing packages... (199/200) 38.86 MiB/40.34 MiB
# Prepared 200 packages in 6.45s
# Installed 200 packages in 248ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.18
#  + aiosignal==1.3.2
#  + alembic==1.15.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + auth0-python==4.9.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.4
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.4.26
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.15.0
#  + coloredlogs==15.0.1
#  + crewai==0.118.0
#  + crewai-tools==0.42.2
#  + cryptography==44.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.12
#  + fastavro==1.10.0
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.6.0
#  + fsspec==2025.3.2
#  + google-auth==2.39.0
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.1
#  + grpcio==1.71.0
#  + h11==0.16.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.30.2
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + importlib-resources==6.5.2
#  + instructor==1.7.9
#  + ipython==8.36.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.44.1
#  + json5==0.12.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.5
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==32.0.1
#  + lancedb==0.22.0
#  + langchain==0.3.25
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.23
#  + langchain-core==0.3.58
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.8
#  + langsmith==0.3.41
#  + litellm==1.67.1
#  + mako==1.3.10
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.95
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.4.3
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.5
#  + oauthlib==3.2.2
#  + onnxruntime==1.21.1
#  + openai==1.77.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.32.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-exporter-otlp-proto-http==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  + opentelemetry-sdk==1.32.1
#  + opentelemetry-semantic-conventions==0.53b1
#  + opentelemetry-util-http==0.53b1
#  + orjson==3.10.18
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + portalocker==2.10.1
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.1
#  + protobuf==5.29.4
#  + psycopg2-binary==2.9.10
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==20.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.4
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.9.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pypdf==5.4.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.400
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.14.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.24.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.40
#  + stack-data==0.6.3
#  + starlette==0.46.2
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.9.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.3
#  + types-requests==2.32.0.20250328
#  + typing-extensions==4.13.2
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.0
#  + tzdata==2025.2
#  + urllib3==2.4.0
#  + uv==0.7.2
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.20.0
#  + zipp==3.21.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 43866e42-5af6-4256-be6c-39a2aac598f9                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
#        Status: Executing Task...
#
# 🚀 Crew: crew
# └── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
# └── 🧠 Thinking...
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Introduction of GPT-4.5**: In early 2024, OpenAI released GPT-4.5, which features enhanced contextual understanding and more efficient fine-tuning capabilities. This update improves performance across specific tasks like coding, legal analysis, and creative writing.
#
# 2. **Multimodal Capabilities**: AI LLMs have increasingly integrated multimodal capabilities, allowing them to process and generate not just text, but also images, audio, and video content. This shift towards multimodality has led to more versatile applications in areas like digital marketing and content creation.
#
# 3. **Improved Fine-Tuning Methodologies**: The development of advanced few-shot and zero-shot learning techniques has enabled LLMs to perform better with minimal task-specific training, drastically reducing the time and resources needed for model adaptation.
#
# 4. **Ethics and Bias Mitigation**: In response to growing concerns over bias and ethical implications, researchers have developed new algorithms focused on bias detection and mitigation strategies, enhancing the fairness and accountability of AI-generated content.
#
# 5. **Open-Source LLMs**: The trend towards open-source AI LLMs has continued, with platforms like Hugging Face enabling researchers and developers to fine-tune and deploy models while democratizing access to powerful AI tools.
#
# 6. **Real-Time Collaboration Tools**: AI LLMs are being integrated into collaboration software. Tools like Notion and Microsoft Teams are incorporating these models to assist users in brainstorming, drafting documents, and generating automated responses in real time.
#
# 7. **Regulatory Frameworks**: In 2024, various governments have made strides in establishing regulatory frameworks that govern the use of AI LLMs, focusing on issues related to data privacy, copyright infringement, and the safe deployment of AI technologies.
#
# 8. **Domain-Specific Models**: 2024 has seen an upswing in the development of domain-specific AI LLMs tailored to industries such as healthcare, finance, and legal sectors, providing improved accuracy and relevance in specialized tasks.
#
# 9. **Human-AI Collaboration**: A focus on enhancing human-AI collaboration is shaping how businesses implement LLMs, emphasizing how these models can augment human capabilities rather than replace them, fostering a more integrated approach to AI solutions.
#
# 10. **Environmental Impact Considerations**: As AI LLMs continue to grow, there's a significant push towards sustainability. Research is being conducted on optimizing power consumption and reducing the carbon footprint of training large-scale models, prompting industry leaders to adopt greener practices.
#
#
# 🚀 Crew: crew
# └── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
#        Assigned to: AI LLMs Senior Data Researcher
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: ee6132ed-17bf-48cd-aec8-283019b90fbe                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 941c07ec-8c8f-473b-8e8f-6c72fd0d8274
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 941c07ec-8c8f-473b-8e8f-6c72fd0d8274
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Comprehensive Report on the Advancement of AI LLMs in 2024
#
# ## 1. Introduction of GPT-4.5
# In early 2024, OpenAI launched GPT-4.5, marking a significant advancement in the capabilities of language models. This new iteration features enhanced contextual understanding, which allows the model to comprehend complex queries and generate responses that are not only contextually relevant but also rich in detail. One of the standout improvements with GPT-4.5 is its fine-tuning capabilities, which have been optimized for performance across various tasks including coding, legal analysis, and creative writing. The model can now learn from fewer examples, making it more efficient in adapting to the needs of different users. This improved performance facilitates a range of applications, from generating code snippets to drafting legal documents, showcasing the versatility and effectiveness of modern AI LLMs.
#
# ## 2. Multimodal Capabilities
# AI LLMs are no longer limited to processing text alone; they are increasingly acquiring multimodal capabilities. This shift allows these models to handle and generate not just textual information, but also images, audio, and video content. For instance, AI systems now can analyze or generate visual content alongside textual descriptions, making them particularly valuable in fields such as digital marketing and content creation. The integration of multimodal functionalities enables more engaging and interactive user experiences, allowing for richer representation of information and facilitating innovative applications such as creating marketing campaigns that utilize both video and text elements.
#
# ## 3. Improved Fine-Tuning Methodologies
# The realm of fine-tuning has experienced noteworthy transformations with the advent of advanced few-shot and zero-shot learning techniques. These methodologies enable AI LLMs to excel with minimal task-specific training. For organizations and researchers, this translates into significant resource savings in terms of time and computational power. The ability of LLMs to generalize from limited examples enhances their adaptability across diverse applications, ensuring higher performance levels without the need for extensive datasets. Such efficiency not only accelerates the deployment of AI solutions but also democratizes access to powerful AI tools, enabling even small enterprises to harness the potential of LLMs.
#
# ## 4. Ethics and Bias Mitigation
# As the deployment of AI technologies becomes more widespread, concerns over bias and ethical implications have grown substantially. In 2024, researchers have developed new algorithms specifically aimed at bias detection and mitigation, which enhance the fairness and accountability of AI-generated content. These initiatives include regular audits of algorithms to identify and address potential biases in training datasets, ensuring that models produce equitable outcomes across various demographics. By prioritizing ethics in the development process, researchers strive to create AI systems that uphold values of inclusivity and justice, ultimately fostering public trust in AI technologies.
#
# ## 5. Open-Source LLMs
# The trend towards open-source AI LLMs continues to gain momentum, with platforms like Hugging Face leading the charge. These open-source frameworks empower researchers and developers to fine-tune and deploy sophisticated models while democratizing access to advanced AI tools. This movement allows smaller organizations to leverage the capabilities of AI LLMs without the substantial costs typically associated with proprietary solutions. Furthermore, the collaborative nature of open-source projects accelerates innovation within the AI community, facilitating shared advancements and collective problem-solving.
#
# ## 6. Real-Time Collaboration Tools
# The integration of AI LLMs into collaboration software marks a new era in workplace productivity. Tools like Notion and Microsoft Teams are incorporating these models to enhance user experience by providing real-time assistance in brainstorming sessions, drafting documents, and generating automated responses. Such integrations streamline workflows, allowing teams to collaborate more effectively and efficiently. The capabilities of AI LLMs to assist in real-time not only improve the quality of work outputs but also foster creativity and idea generation among team members.
#
# ## 7. Regulatory Frameworks
# In 2024, numerous governments around the world have made significant strides in establishing regulatory frameworks that govern the use of AI LLMs. These regulations focus on critical issues such as data privacy, copyright infringement, and the safe deployment of AI technologies. As AI becomes integral to various sectors, regulatory bodies aim to ensure that the deployment of AI systems aligns with ethical and legal standards, protecting individuals and organizations alike. The establishment of clear guidelines serves as a critical step towards fostering responsible AI use and mitigating risks associated with its adoption.
#
# ## 8. Domain-Specific Models
# The development of domain-specific AI LLMs has gained traction in 2024, with models tailored to specialized industries such as healthcare, finance, and legal sectors. These domain-specific adaptations enhance the accuracy and relevance of AI outputs, making them more suitable for addressing industry-specific challenges. For example, in healthcare, AI LLMs can assist in generating accurate medical documentation, while in finance, they can analyze regulatory texts. By creating models designed for particular fields, organizations can achieve improved outcomes and deliver more relevant solutions to their clients.
#
# ## 9. Human-AI Collaboration
# The emphasis on human-AI collaboration reflects a growing recognition of the potential of AI LLMs to augment human capabilities rather than replace them. In 2024, this approach is shaping how businesses implement AI solutions, fostering a culture of integration where AI acts as a tool that empowers employees. Organizations are increasingly focusing on training staff to work alongside AI systems, illustrating how human expertise and machine intelligence can blend to enhance decision-making processes and operational efficiency, leading to stronger overall performance.
#
# ## 10. Environmental Impact Considerations
# As AI LLMs rapidly evolve, there is an increasing emphasis on sustainability and environmental impact. In 2024, research initiatives have begun to focus on optimizing the power consumption of large-scale model training and reducing the overall carbon footprint associated with AI technologies. Industry leaders are being prompted to adopt greener practices, including utilizing renewable energy resources and developing more energy-efficient training algorithms. This commitment to sustainability reflects a broader recognition within the tech community of the need to minimize the environmental impact of AI advancements while pursuing innovation.
#
# Through these multiple facets, 2024 stands out as a pivotal year in the evolution of AI language models, showcasing advancements that enhance their capabilities, improve ethical standards, and promote interdisciplinary collaboration, all while considering their environmental impact.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 941c07ec-8c8f-473b-8e8f-6c72fd0d8274
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: ee6132ed-17bf-48cd-aec8-283019b90fbe
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 941c07ec-8c8f-473b-8e8f-6c72fd0d8274
#        Assigned to: AI LLMs Reporting Analyst
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 941c07ec-8c8f-473b-8e8f-6c72fd0d8274                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 43866e42-5af6-4256-be6c-39a2aac598f9                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
